# %%
import pandas as pd

# Step 1: Load the CSV file
df = pd.read_csv('/home/alien/Git/XSpeech/data_processing/transcription_small_tt_nowordrep_formatted.csv')  # Replace 'your_file.csv' with your actual file name

# Step 2: Create the new 'fluent' column
df['fluent'] = df['filepath'].apply(lambda x: '/home/alien/Git/DATA/MeloTTSAudioSmall/' + x.split('/')[-1])

# Step 3: Save the modified DataFrame to a new CSV file
df.to_csv('/home/alien/Git/XSpeech/data_processing/transcription_small_tt_nowordrep_formatted.csv', index=False)  # Replace 'modified_file.csv' with your desired output file name
